# %% [markdown]
# # Test qWGAN

# %% [markdown]
# ## 1. Single run

# %%
from config import CFG
from tools.training_init import run_single_training
from time import perf_counter as tpc
import copy

# %%
config = copy.deepcopy(CFG)

config.run_multiple_experiments = False
config.system_size = 2
config.extra_ancilla = False
config.epochs = 1
config.iterations_epoch = 3
config.gen_layers = 1
config.gen_ansatz = "XX_YY_ZZ_Z"
config.target_hamiltonian = "custom_h"
config.custom_hamiltonian_terms = ["ZZZ", "ZZ", "XX", "XZ"]
config.label_suffix = "c1_2q_1l_noanc_XXYYZZZ_CustomH_ZZZ"

# %%
t0 = tpc()
res = run_single_training(config=config)
t1 = tpc()
print(f'Runtime = {t1-t0}s')
# Out:
# Running in SINGLE RUN mode.
#
#
# ==================================================
# run_timestamp: 2025-07-23__11-36-47,
# ----------------------------------------------
# load_timestamp: None,
# type_of_warm_start: none,
# warm_start_strength: 0.1,
# ----------------------------------------------
# system_size: 2,
# extra_ancilla: False,
# ancilla_mode: pass,
# ancilla_project_norm: re-norm,
# ancilla_topology: bridge,
# ancilla_connect_to: None,
# do_ancilla_1q_gates: False,
# start_ancilla_gates_randomly: False,
# ----------------------------------------------
# gen_layers: 1,
# gen_ansatz: XX_YY_ZZ_Z,
# ----------------------------------------------
# target_hamiltonian: custom_h,
# custom_hamiltonian_terms: ['ZZZ', 'ZZ', 'XX', 'XZ'],
# custom_hamiltonian_strengths: [1.0, 0.1],
# ----------------------------------------------
# epochs: 1,
# iterations_epoch: 3,
# log_every_x_iter: 10,
# save_fid_and_loss_every_x_iter: 1,
# max_fidelity: 0.99,
# steps_gen: 1,
# steps_dis: 1,
# ----------------------------------------------
# l_rate: 0.01,
# momentum_coeff: 0.9,
# ==================================================
#
#
# Starting training from scratch (no timestamp specified).
#
# ==================================================
#
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
#
# epoch:   1 | iters:   1 | fidelity:0.013989 | loss:-4.421417
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
# (16, 1) (16, 1) (16, 1) (16, 16) (16, 16)
#
# ==================================================
#
#
# The number of epochs exceeds 1.
#
# Run took: 0:00:00.058890 time.
#
# Default configuration run COMPLETED SUCCESSFULLY.
#
# Runtime = 0.07803219999186695s

# %%
t0 = tpc()
res = run_single_training(config=config, verbose=False, seed=42)
t1 = tpc()
print(f'Runtime = {t1-t0}s')
# Out:
# Runtime = 0.06403510004747659s

# %%
import tools.training_init
import qgan.cost_functions
from qgan.training import Training
from qgan.generator import Generator
from qgan.discriminator import Discriminator

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %load_ext line_profiler
# %lprun -f tools.training_init.run_single_training -f Training.run -f qgan.cost_functions.braket -f Generator.update_gen -f Generator._grad_theta -f Generator.get_total_gen_grad -f Discriminator.update_dis -f Discriminator._compute_grad -f Discriminator._grad_alpha -f Discriminator._grad_beta -f Discriminator._grad_psi_or_phi -f Discriminator run_single_training(config=config, verbose=False)
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\line_profiler\ipython_extension.py:97: UserWarning: Could not extract a code object for the object <class 'qgan.discriminator.Discriminator'>
#   profile = LineProfiler(*funcs)
# Timer unit: 1e-07 s
#
# Total time: 0.0191979 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\cost_functions.py
# Function: braket at line 23
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     23                                           def braket(*args) -> float:
#     24                                               """Calculate the braket (inner product) between two quantum states.
#     25
#     26                                               Args:
#     27                                                   args: The arguments can be either two vectors (bra and ket), three (bra, operator, ket) or bigger (bra, operator^N, ket).
#     28
#     29                                               Returns:
#     30                                                   float: The inner product of the two vectors.
#     31                                               """
#     32      1161       6230.0      5.4      3.2      bra, *ops, ket = args
#     33
#     34      2703       8429.0      3.1      4.4      for op in ops:
#     35      1542      65750.0     42.6     34.2          ket = np.matmul(op, ket)
#     36      1161     111570.0     96.1     58.1      return np.matmul(bra.getH(), ket)
#
# Total time: 0.0583079 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: update_dis at line 116
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    116                                               def update_dis(self, final_target_state: np.ndarray, final_gen_state: np.ndarray):
#    117                                                   """Update the discriminator parameters (alpha, beta) using the gradients.
#    118
#    119                                                   Args:
#    120                                                       final_target_state (np.ndarray): The final target state of the system.
#    121                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    122                                                   """
#    123                                                   ################################################################
#    124                                                   # Get the current Discriminator state:
#    125                                                   ################################################################
#    126         3      21823.0   7274.3      3.7          A, B, _, _ = self.get_dis_matrices_rep()
#    127
#    128                                                   ####################################################
#    129                                                   # Update alpha
#    130                                                   ####################################################
#    131         3     277586.0  92528.7     47.6          grad_alpha = self._compute_grad(final_target_state, final_gen_state, A, B, "alpha")
#    132         3       4314.0   1438.0      0.7          new_alpha = self.optimizer_psi.move_in_grad(self.alpha, grad_alpha, "max")
#    133
#    134                                                   ####################################################
#    135                                                   # Update beta
#    136                                                   ####################################################
#    137         3     275054.0  91684.7     47.2          grad_beta = self._compute_grad(final_target_state, final_gen_state, A, B, "beta")
#    138         3       4254.0   1418.0      0.7          new_beta = self.optimizer_phi.move_in_grad(self.beta, grad_beta, "max")
#    139
#    140                                                   # Update the parameters later, to avoid affecting gradient computations:
#    141         3         31.0     10.3      0.0          self.alpha = new_alpha
#    142         3         17.0      5.7      0.0          self.beta = new_beta
#
# Total time: 0.0551861 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _compute_grad at line 144
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    144                                               def _compute_grad(self, final_target_state, final_gen_state, A, B, param: str) -> np.ndarray:
#    145                                                   """Calculate the gradient of the discriminator with respect to the param (alpha or beta).
#    146
#    147                                                   Args:
#    148                                                       final_target_state (np.ndarray): The final target state of the system.
#    149                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    150                                                       A (np.ndarray): expm(-1/lamb * phi), with phi being the matrix repr. of the imag part of the dis.
#    151                                                       B (np.ndarray): expm(1/lamb * psi), with psi being the matrix repr. of the real part of the dis.
#    152                                                       param (str): The parameter to compute the gradient for ("alpha" or "beta").
#    153
#    154                                                   Returns:
#    155                                                       np.ndarray: The gradient of the discriminator with respect to beta.
#    156                                                   """
#    157                                                   ################################################################
#    158                                                   # Initialize gradients on 0:
#    159                                                   #################################################################
#    160         6         47.0      7.8      0.0          zero_param = self.alpha if param == "alpha" else self.beta
#    161         6        433.0     72.2      0.1          grad_psi_term = np.zeros_like(zero_param, dtype=complex)
#    162         6        339.0     56.5      0.1          grad_phi_term = np.zeros_like(zero_param, dtype=complex)
#    163         6        304.0     50.7      0.1          grad_reg_term = np.zeros_like(zero_param, dtype=complex)
#    164
#    165        30        158.0      5.3      0.0          for type in range(len(self.herm)):
#    166                                                       ###########################################################
#    167                                                       # Compute the alpha or beta gradient step:
#    168                                                       ############################################################
#    169        24        182.0      7.6      0.0              grad_step = self._grad_alpha if param == "alpha" else self._grad_beta if param == "beta" else None
#    170        24     548623.0  22859.3     99.4              gradpsi_list, gradphi_list, gradreg_list = grad_step(final_target_state, final_gen_state, A, B, type)
#    171
#    172                                                       # Add grad of psi, phi and reg terms
#    173        24        643.0     26.8      0.1              grad_psi_term[:, type] = np.asarray(gradpsi_list)
#    174        24        415.0     17.3      0.1              grad_phi_term[:, type] = np.asarray(gradphi_list)
#    175        24        348.0     14.5      0.1              grad_reg_term[:, type] = np.asarray(gradreg_list)
#    176
#    177         6        336.0     56.0      0.1          grad = np.real(grad_psi_term - grad_phi_term - grad_reg_term)
#    178
#    179         6         33.0      5.5      0.0          return np.asarray(grad)
#
# Total time: 0.0273466 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _grad_alpha at line 181
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    181                                               def _grad_alpha(self, final_target_state, final_gen_state, A: np.ndarray, B: np.ndarray, type: str) -> np.ndarray:
#    182                                                   """Calculate a step of the gradient of the discriminator with respect to alpha.
#    183
#    184                                                   Args:
#    185                                                       final_target_state (np.ndarray): The final target state of the system.
#    186                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    187                                                       A (np.ndarray): expm(-1/lamb * phi), with phi being the matrix repr. of the imag part of the dis.
#    188                                                       B (np.ndarray): expm(1/lamb * psi), with psi being the matrix repr. of the real part of the dis.
#    189                                                       type (str): The type of hermitian operator (0: I, 1: X, 2: Y, 3: Z).
#    190
#    191                                                   Returns:
#    192                                                       tuple: A tuple containing the gradients of psi, phi, and regularization terms.
#    193                                                   """
#    194        12         68.0      5.7      0.0          cs = 1 / lamb
#    195
#    196        12     143280.0  11940.0     52.4          gradpsi: list = self._grad_psi_or_phi(type, respect_to="psi")
#    197        12         43.0      3.6      0.0          gradpsi_list, gradphi_list, gradreg_list = [], [], []
#    198
#    199                                                   # fmt: off
#    200        60        230.0      3.8      0.1          for grad_psi in gradpsi:
#    201                                                       ##################################################################
#    202                                                       # Compute the gradient of psi with respect to alpha
#    203                                                       ##################################################################
#    204        48       9296.0    193.7      3.4              gradpsi_list.append(np.ndarray.item(braket(final_target_state, grad_psi, final_target_state)))
#    205
#    206                                                       ##################################################################
#    207                                                       # No gradient of phi with respect to alpha, so append 0
#    208                                                       ##################################################################
#    209        48        142.0      3.0      0.1              gradphi_list.append(0)
#    210
#    211                                                       ##################################################################
#    212                                                       # Compute the regularization terms:
#    213                                                       ##################################################################
#    214        48      27082.0    564.2      9.9              term1 = cs * braket(final_gen_state, A, final_gen_state) * braket(final_target_state, grad_psi, B, final_target_state)
#    215        48      26815.0    558.6      9.8              term2 = cs * braket(final_gen_state, grad_psi, B, final_target_state) * braket(final_target_state, A, final_gen_state)
#    216        48      26649.0    555.2      9.7              term3 = cs * braket(final_gen_state, A, final_target_state) * braket(final_target_state, grad_psi, B, final_gen_state)
#    217        48      26697.0    556.2      9.8              term4 = cs * braket(final_gen_state, grad_psi, B, final_gen_state) * braket(final_target_state, A, final_target_state)
#    218        48      13114.0    273.2      4.8              gradreg_list.append(np.ndarray.item(lamb / np.e * (cst1 * term1 - cst2 * (term2 + term3) + cst3 * term4)))
#    219                                                   # fmt: on
#    220
#    221        12         50.0      4.2      0.0          return gradpsi_list, gradphi_list, gradreg_list
#
# Total time: 0.0271391 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _grad_beta at line 223
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    223                                               def _grad_beta(self, final_target_state, final_gen_state, A: np.ndarray, B: np.ndarray, type: str):
#    224                                                   """Calculate a step of the gradient of the discriminator with respect to beta.
#    225
#    226                                                   Args:
#    227                                                       final_target_state (np.ndarray): The final target state of the system.
#    228                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    229                                                       A (np.ndarray): expm(-1/lamb * phi), with phi being the matrix repr. of the imag part of the dis.
#    230                                                       B (np.ndarray): expm(1/lamb * psi), with psi being the matrix repr. of the real part of the dis.
#    231                                                       type (str): The type of hermitian operator (0: I, 1: X, 2: Y, 3: Z).
#    232
#    233                                                   Returns:
#    234                                                       tuple: A tuple containing the gradients of psi, phi, and regularization terms.
#    235                                                   """
#    236        12         63.0      5.2      0.0          cs = -1 / lamb
#    237
#    238        12     142032.0  11836.0     52.3          gradphi: list = self._grad_psi_or_phi(type, respect_to="phi")
#    239        12         42.0      3.5      0.0          gradpsi_list, gradphi_list, gradreg_list = [], [], []
#    240
#    241                                                   # fmt: off
#    242        60        249.0      4.2      0.1          for grad_phi in gradphi:
#    243                                                       ##################################################################
#    244                                                       # No gradient of psi with respect to beta, so append 0
#    245                                                       ##################################################################
#    246        48        146.0      3.0      0.1              gradpsi_list.append(0)
#    247
#    248                                                       ##################################################################
#    249                                                       # Compute the gradient of phi with respect to beta
#    250                                                       ##################################################################
#    251        48       8944.0    186.3      3.3              gradphi_list.append(np.ndarray.item(braket(final_gen_state, grad_phi, final_gen_state)))
#    252
#    253                                                       ##################################################################
#    254                                                       # Compute the regularization terms:
#    255                                                       ##################################################################
#    256        48      26840.0    559.2      9.9              term1 = cs * braket(final_gen_state, grad_phi, A, final_gen_state) * braket(final_target_state, B, final_target_state)
#    257        48      26795.0    558.2      9.9              term2 = cs * braket(final_gen_state, B, final_target_state) * braket(final_target_state, grad_phi, A, final_gen_state)
#    258        48      26647.0    555.1      9.8              term3 = cs * braket(final_gen_state, grad_phi, A, final_target_state) * braket(final_target_state, B, final_gen_state)
#    259        48      26631.0    554.8      9.8              term4 = cs * braket(final_gen_state, B, final_gen_state) * braket(final_target_state, grad_phi, A, final_target_state)
#    260        48      12955.0    269.9      4.8              gradreg_list.append(np.ndarray.item(lamb / np.e * (cst1 * term1 - cst2 * (term2 + term3) + cst3 * term4)))
#    261                                                   # fmt: on
#    262
#    263        12         47.0      3.9      0.0          return gradpsi_list, gradphi_list, gradreg_list
#
# Total time: 0.027188 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _grad_psi_or_phi at line 266
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    266                                               def _grad_psi_or_phi(self, type: int, respect_to: str) -> list:
#    267                                                   """Calculate the gradient of the discriminator with respect to psi/phi.
#    268
#    269                                                   Args:
#    270                                                       type (int): The type of hermitian operator (0: I, 1: X, 2: Y, 3: Z).
#    271                                                       psi_or_phi (str): Specify whether to compute the gradient for psi or phi.
#    272
#    273                                                   Returns:
#    274                                                       list: A list of gradients for each qubit in the discriminator, respect psi/phi.
#    275                                                   """
#    276                                                   ########################################################################
#    277                                                   # Chose respect which variable to compute the gradient (alpha or beta)
#    278                                                   ########################################################################
#    279        24        119.0      5.0      0.0          coefficients = self.alpha if respect_to == "psi" else self.beta
#    280
#    281                                                   ########################################################################
#    282                                                   # Compute gradients for each qubit:
#    283                                                   ########################################################################
#    284        24         79.0      3.3      0.0          grad_matrix = []
#    285       120        427.0      3.6      0.2          for i in range(self.size):
#    286        96        261.0      2.7      0.1              grad_matrix_I = 1
#    287       480       1600.0      3.3      0.6              for j in range(self.size):
#    288       384       1105.0      2.9      0.4                  if i == j:
#    289        96        358.0      3.7      0.1                      grad_matrix_j = self.herm[type]
#    290                                                           else:
#    291       288      16271.0     56.5      6.0                      grad_matrix_j = np.zeros_like(self.herm[0], dtype=complex)
#    292      1440       5302.0      3.7      2.0                      for k, herm_k in enumerate(self.herm):
#    293      1152      59733.0     51.9     22.0                          grad_matrix_j += coefficients[j][k] * herm_k
#    294       384     186247.0    485.0     68.5                  grad_matrix_I = np.kron(grad_matrix_I, grad_matrix_j)
#    295        96        303.0      3.2      0.1              grad_matrix.append(grad_matrix_I)
#    296        24         75.0      3.1      0.0          return grad_matrix
#
# Total time: 0.0193189 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\generator.py
# Function: get_total_gen_grad at line 68
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     68                                               def get_total_gen_grad(self, index) -> np.ndarray:
#     69                                                   """Get the total generator gradient for a specific gate index.
#     70
#     71                                                   Args:
#     72                                                       index (int): The index of the gate for which to compute the gradient.
#     73
#     74                                                   Returns:
#     75                                                       np.ndarray: The total generator gradient vector for the specified gate.
#     76                                                   """
#     77        15     192138.0  12809.2     99.5          Untouched_x_G_grad_i = np.kron(Identity(self.config.system_size), self.qc.get_grad_mat_rep(index))
#     78        15       1051.0     70.1      0.5          return np.matmul(Untouched_x_G_grad_i, self.total_input_state)
#
# Total time: 0.0327737 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\generator.py
# Function: update_gen at line 80
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     80                                               def update_gen(self, dis: Discriminator, final_target_state: np.ndarray):
#     81                                                   """Update the generator parameters (angles) using the optimizer.
#     82
#     83                                                   Args:
#     84                                                       dis (Discriminator): The discriminator to compute gradients.
#     85                                                       final_target_state (np.ndarray): The target state vector.
#     86                                                   """
#     87                                                   ###############################################################
#     88                                                   # Compute the gradient
#     89                                                   ###############################################################
#     90         3     294833.0  98277.7     90.0          grad: np.ndarray = self._grad_theta(dis, final_target_state, self.total_gen_state)
#     91
#     92                                                   # Get the new thetas from the gradient
#     93        18        142.0      7.9      0.0          theta = np.asarray([gate.angle for gate in self.qc.gates])
#     94         3       1437.0    479.0      0.4          new_theta = self.optimizer.move_in_grad(theta, grad, "min")
#     95
#     96                                                   ###############################################################
#     97                                                   # Update the angles in the quantum circuit
#     98                                                   ###############################################################
#     99        18         72.0      4.0      0.0          for i in range(self.qc.depth):
#    100        15         71.0      4.7      0.0              self.qc.gates[i].angle = new_theta[i]
#    101
#    102                                                   ###############################################################
#    103                                                   # Update the total generator state with the new angles
#    104                                                   ###############################################################
#    105         3      31182.0  10394.0      9.5          self.total_gen_state = self.get_total_gen_state()
#
# Total time: 0.0293483 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\generator.py
# Function: _grad_theta at line 107
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    107                                               def _grad_theta(
#    108                                                   self,
#    109                                                   dis: Discriminator,
#    110                                                   final_target_state: np.ndarray,
#    111                                                   total_gen_state: np.ndarray,
#    112                                               ) -> np.ndarray:
#    113                                                   """Compute the gradient of the generator parameters (angles) with respect to the discriminator's output.
#    114
#    115                                                   Args:
#    116                                                       dis (Discriminator): The discriminator to compute gradients.
#    117                                                       final_target_state (np.ndarray): The target state vector.
#    118                                                       total_gen_state (np.ndarray): The current generator state vector.
#    119
#    120                                                   Returns:
#    121                                                       np.ndarray: The gradient of the generator parameters.
#    122                                                   """
#    123                                                   #######################################################################
#    124                                                   # Get the current Generator, Target and Discriminator states:
#    125                                                   #######################################################################
#    126         3         85.0     28.3      0.0          final_gen_state = get_final_gen_state_for_discriminator(total_gen_state)
#    127         3      24270.0   8090.0      8.3          A, B, _, phi = dis.get_dis_matrices_rep()
#    128
#    129         3         16.0      5.3      0.0          grad_g_psi, grad_g_phi, grad_g_reg = [], [], []
#    130
#    131        18        133.0      7.4      0.0          for i in range(self.qc.depth):
#    132                                                       # fmt: off
#    133                                                       # For psi term
#    134        15         63.0      4.2      0.0              grad_g_psi.append(0)
#    135
#    136                                                       # For phi term
#    137        15     193761.0  12917.4     66.0              total_gen_grad = self.get_total_gen_grad(i)
#    138        15        335.0     22.3      0.1              final_gen_grad = get_final_gen_state_for_discriminator(total_gen_grad)
#    139        15       6925.0    461.7      2.4              tmp_grad = braket(final_gen_grad, phi, final_gen_state) + braket(final_gen_state, phi, final_gen_grad)
#    140        15        164.0     10.9      0.1              grad_g_phi.append(np.ndarray.item(tmp_grad))
#    141
#    142                                                       # For reg term
#    143        15       7393.0    492.9      2.5              term1 = braket(final_gen_grad, A, final_gen_state) * braket(final_target_state, B, final_target_state)
#    144        15       7111.0    474.1      2.4              term2 = braket(final_gen_state, A, final_gen_grad) * braket(final_target_state, B, final_target_state)
#    145        15       7113.0    474.2      2.4              term3 = braket(final_gen_grad, B, final_target_state) * braket(final_target_state, A, final_gen_state)
#    146        15       7155.0    477.0      2.4              term4 = braket(final_gen_state, B, final_target_state) * braket(final_target_state, A, final_gen_grad)
#    147        15       7097.0    473.1      2.4              term5 = braket(final_gen_grad, A, final_target_state) * braket(final_target_state, B, final_gen_state)
#    148        15       7119.0    474.6      2.4              term6 = braket(final_gen_state, A, final_target_state) * braket(final_target_state, B, final_gen_grad)
#    149        15       7010.0    467.3      2.4              term7 = braket(final_gen_grad, B, final_gen_state) * braket(final_target_state, A, final_target_state)
#    150        15       6865.0    457.7      2.3              term8 = braket(final_gen_state, B, final_gen_grad) * braket(final_target_state, A, final_target_state)
#    151        15      10334.0    688.9      3.5              tmp_reg_grad = self.config.lamb / np.e * (self.config.cst1 * (term1 + term2) - self.config.cst2 * (term3 + term4 + term5 + term6) + self.config.cst3 * (term7 + term8))
#    152
#    153        15        161.0     10.7      0.1              grad_g_reg.append(np.ndarray.item(tmp_reg_grad))
#    154                                                       # fmt: on
#    155
#    156         3         53.0     17.7      0.0          g_psi = np.asarray(grad_g_psi)
#    157         3         44.0     14.7      0.0          g_phi = np.asarray(grad_g_phi)
#    158         3         30.0     10.0      0.0          g_reg = np.asarray(grad_g_reg)
#    159
#    160         3        234.0     78.0      0.1          grad = np.real(g_psi - g_phi - g_reg)
#    161
#    162         3         12.0      4.0      0.0          return np.asarray(grad)
#
# Total time: 0.0974935 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\training.py
# Function: run at line 59
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     59                                               def run(self):
#     60                                                   """Run the training, saving the data, the model, the logs, and the results plots."""
#     61
#     62                                                   ###########################################################
#     63                                                   # Initialize training
#     64                                                   ###########################################################
#     65         1          6.0      6.0      0.0          if self.verbose:
#     66                                                       print_and_log("\n" + self.config.show_data(), self.config.log_path)
#     67
#     68                                                   # Load models if specified (only the params, and only if compatible)
#     69         1         43.0     43.0      0.0          load_models_if_specified(self, verbose=self.verbose)
#     70
#     71         1          4.0      4.0      0.0          fidelities_history, losses_history = [], []
#     72         1         63.0     63.0      0.0          starttime = datetime.now()
#     73         1          4.0      4.0      0.0          num_epochs: int = 0
#     74
#     75                                                   ###########################################################
#     76                                                   # Main Training Block
#     77                                                   ###########################################################
#     78         1          3.0      3.0      0.0          while True:
#     79                                                       # while (f < 0.95):
#     80         1          4.0      4.0      0.0              fidelities = []
#     81         1          2.0      2.0      0.0              losses = []
#     82         1          4.0      4.0      0.0              num_epochs += 1
#     83         4         27.0      6.8      0.0              for epoch_iter in range(self.config.iterations_epoch):
#     84                                                           ###########################################################
#     85                                                           # Gen and Dis gradient descent
#     86                                                           ###########################################################
#     87         6         36.0      6.0      0.0                  for _ in range(self.config.steps_gen):
#     88         3     328035.0 109345.0     33.6                      self.gen.update_gen(self.dis, self.final_target_state)
#     89
#     90                                                           # Remove ancilla if needed, with ancilla mode, before discriminator:
#     91         3         79.0     26.3      0.0                  final_gen_state = get_final_gen_state_for_discriminator(self.gen.total_gen_state)
#     92
#     93         6         38.0      6.3      0.0                  for _ in range(self.config.steps_dis):
#     94         3     583300.0 194433.3     59.8                      self.dis.update_dis(self.final_target_state, final_gen_state)
#     95
#     96                                                           ###########################################################
#     97                                                           # Every X iterations: compute and save fidelity & loss
#     98                                                           ###########################################################
#     99         3         54.0     18.0      0.0                  if epoch_iter % self.config.save_fid_and_loss_every_x_iter == 0:
#    100         3      32640.0  10880.0      3.3                      fid, loss = compute_fidelity_and_cost(self.dis, self.final_target_state, final_gen_state)
#    101         3         24.0      8.0      0.0                      fidelities.append(fid), losses.append(loss)
#    102
#    103                                                           ############################################################
#    104                                                           # Every X iterations: Print and log fidelity and loss
#    105                                                           ############################################################
#    106         3         21.0      7.0      0.0                  if epoch_iter % self.config.log_every_x_iter == 0:
#    107         2        151.0     75.5      0.0                      info = "\nepoch:{:4d} | iters:{:4d} | fidelity:{:8f} | loss:{:8f}".format(
#    108         1        196.0    196.0      0.0                          num_epochs, epoch_iter + 1, round(fid, 6), round(loss, 6)
#    109                                                               )
#    110         1          7.0      7.0      0.0                      if self.verbose:
#    111                                                                   print_and_log(info, self.config.log_path)
#    112
#    113                                                       ###########################################################
#    114                                                       # End of epoch, store data and plot
#    115                                                       ###########################################################
#    116         1        201.0    201.0      0.0              fidelities_history = np.append(fidelities_history, fidelities)
#    117         1         79.0     79.0      0.0              losses_history = np.append(losses_history, losses)
#    118                                                       #plt_fidelity_vs_iter(fidelities_history, losses_history, CFG, num_epochs)
#    119
#    120                                                       #############################################################
#    121                                                       # Stopping conditions
#    122                                                       #############################################################
#    123         1          3.0      3.0      0.0              if num_epochs >= self.config.epochs:
#    124         1          3.0      3.0      0.0                  if self.verbose:
#    125                                                               print_and_log("\n==================================================\n", self.config.log_path)
#    126                                                               print_and_log(f"\nThe number of epochs exceeds {self.config.epochs}.", self.config.log_path)
#    127         1          4.0      4.0      0.0                  break
#    128
#    129                                                       if fidelities[-1] > self.config.max_fidelity:  # TODO: Maybe change this cond, to use max(fidelities)?
#    130                                                           if self.verbose:
#    131                                                               print_and_log("\n==================================================\n", self.config.log_path)
#    132                                                               print_and_log(
#    133                                                                   f"\nThe fidelity {fidelities[-1]} exceeds the maximum {self.config.max_fidelity}.",
#    134                                                                   self.config.log_path,
#    135                                                               )
#    136                                                           break
#    137
#    138                                                   ###########################################################
#    139                                                   # End training, save all data into files
#    140                                                   ###########################################################
#    141                                                   # Save data of fidelity and loss
#    142         1       9420.0   9420.0      1.0          save_fidelity_loss(fidelities_history, losses_history, self.config.fid_loss_path)
#    143
#    144                                                   # Save data of the generator and the discriminator
#    145         1       5215.0   5215.0      0.5          save_model(self.gen, self.config.model_gen_path)
#    146         1       5041.0   5041.0      0.5          save_model(self.dis, self.config.model_dis_path)
#    147
#    148                                                   # Output the parameters of the generator
#    149         1      10151.0  10151.0      1.0          save_gen_final_params(self.gen, self.config.gen_final_params_path)
#    150
#    151         1         65.0     65.0      0.0          endtime = datetime.now()
#    152         1          7.0      7.0      0.0          if self.verbose:
#    153                                                       print_and_log(f"\nRun took: {endtime - starttime} time.", self.config.log_path)
#    154
#    155         1          5.0      5.0      0.0          return losses_history, fidelities_history
#
# Total time: 0.101463 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\tools\training_init.py
# Function: run_single_training at line 35
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     35                                           def run_single_training(config=CFG, verbose=True):
#     36                                               """
#     37                                               Runs a single training instance.
#     38                                               """
#     39         1         13.0     13.0      0.0      if verbose:
#     40                                                   print_and_log("Running in SINGLE RUN mode.\n", config.log_path)
#     41
#     42         1          6.0      6.0      0.0      try:
#     43                                                   ##############################################################
#     44                                                   # Run single training instance with specified configuration
#     45                                                   ##############################################################
#     46         1      39235.0  39235.0      3.9          training_instance = Training(config=config, verbose=verbose)
#     47         1     975360.0 975360.0     96.1          res = training_instance.run()
#     48         1          6.0      6.0      0.0          success_msg = "\nDefault configuration run COMPLETED SUCCESSFULLY.\n"
#     49         1          4.0      4.0      0.0          if verbose:
#     50                                                       print_and_log(success_msg, config.log_path)  # Log to file
#     51         1          3.0      3.0      0.0          return res
#     52
#     53                                               except Exception as e:  # noqa: BLE001
#     54                                                   ##############################################################
#     55                                                   # Handle exceptions during the training run
#     56                                                   ##############################################################
#     57                                                   tb_str = traceback.format_exc()
#     58                                                   error_msg = (
#     59                                                       f"\n{'-' * 60}\n"
#     60                                                       f"FAILED: Default configuration run!\n"
#     61                                                       f"Error Type: {type(e).__name__}\n"
#     62                                                       f"Error Message: {e!s}\n"
#     63                                                       f"Traceback:\n{tb_str}"
#     64                                                       f"{'=' * 60}\n"
#     65                                                   )
#     66                                                   if verbose:
#     67                                                       print_and_log(error_msg, config.log_path)  # Log to file

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %load_ext line_profiler
# %lprun -f tools.training_init.run_single_training -f Training.run -f qgan.cost_functions.braket -f Generator.update_gen -f Generator._grad_theta -f Generator.get_total_gen_grad -f Discriminator.update_dis -f Discriminator._compute_grad -f Discriminator._grad_alpha -f Discriminator._grad_beta -f Discriminator._grad_psi_or_phi -f Discriminator run_single_training(config=config, verbose=False)
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\line_profiler\ipython_extension.py:97: UserWarning: Could not extract a code object for the object <class 'qgan.discriminator.Discriminator'>
#   profile = LineProfiler(*funcs)
# Timer unit: 1e-07 s
#
# Total time: 0.0191979 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\cost_functions.py
# Function: braket at line 23
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     23                                           def braket(*args) -> float:
#     24                                               """Calculate the braket (inner product) between two quantum states.
#     25
#     26                                               Args:
#     27                                                   args: The arguments can be either two vectors (bra and ket), three (bra, operator, ket) or bigger (bra, operator^N, ket).
#     28
#     29                                               Returns:
#     30                                                   float: The inner product of the two vectors.
#     31                                               """
#     32      1161       6230.0      5.4      3.2      bra, *ops, ket = args
#     33
#     34      2703       8429.0      3.1      4.4      for op in ops:
#     35      1542      65750.0     42.6     34.2          ket = np.matmul(op, ket)
#     36      1161     111570.0     96.1     58.1      return np.matmul(bra.getH(), ket)
#
# Total time: 0.0583079 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: update_dis at line 116
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    116                                               def update_dis(self, final_target_state: np.ndarray, final_gen_state: np.ndarray):
#    117                                                   """Update the discriminator parameters (alpha, beta) using the gradients.
#    118
#    119                                                   Args:
#    120                                                       final_target_state (np.ndarray): The final target state of the system.
#    121                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    122                                                   """
#    123                                                   ################################################################
#    124                                                   # Get the current Discriminator state:
#    125                                                   ################################################################
#    126         3      21823.0   7274.3      3.7          A, B, _, _ = self.get_dis_matrices_rep()
#    127
#    128                                                   ####################################################
#    129                                                   # Update alpha
#    130                                                   ####################################################
#    131         3     277586.0  92528.7     47.6          grad_alpha = self._compute_grad(final_target_state, final_gen_state, A, B, "alpha")
#    132         3       4314.0   1438.0      0.7          new_alpha = self.optimizer_psi.move_in_grad(self.alpha, grad_alpha, "max")
#    133
#    134                                                   ####################################################
#    135                                                   # Update beta
#    136                                                   ####################################################
#    137         3     275054.0  91684.7     47.2          grad_beta = self._compute_grad(final_target_state, final_gen_state, A, B, "beta")
#    138         3       4254.0   1418.0      0.7          new_beta = self.optimizer_phi.move_in_grad(self.beta, grad_beta, "max")
#    139
#    140                                                   # Update the parameters later, to avoid affecting gradient computations:
#    141         3         31.0     10.3      0.0          self.alpha = new_alpha
#    142         3         17.0      5.7      0.0          self.beta = new_beta
#
# Total time: 0.0551861 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _compute_grad at line 144
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    144                                               def _compute_grad(self, final_target_state, final_gen_state, A, B, param: str) -> np.ndarray:
#    145                                                   """Calculate the gradient of the discriminator with respect to the param (alpha or beta).
#    146
#    147                                                   Args:
#    148                                                       final_target_state (np.ndarray): The final target state of the system.
#    149                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    150                                                       A (np.ndarray): expm(-1/lamb * phi), with phi being the matrix repr. of the imag part of the dis.
#    151                                                       B (np.ndarray): expm(1/lamb * psi), with psi being the matrix repr. of the real part of the dis.
#    152                                                       param (str): The parameter to compute the gradient for ("alpha" or "beta").
#    153
#    154                                                   Returns:
#    155                                                       np.ndarray: The gradient of the discriminator with respect to beta.
#    156                                                   """
#    157                                                   ################################################################
#    158                                                   # Initialize gradients on 0:
#    159                                                   #################################################################
#    160         6         47.0      7.8      0.0          zero_param = self.alpha if param == "alpha" else self.beta
#    161         6        433.0     72.2      0.1          grad_psi_term = np.zeros_like(zero_param, dtype=complex)
#    162         6        339.0     56.5      0.1          grad_phi_term = np.zeros_like(zero_param, dtype=complex)
#    163         6        304.0     50.7      0.1          grad_reg_term = np.zeros_like(zero_param, dtype=complex)
#    164
#    165        30        158.0      5.3      0.0          for type in range(len(self.herm)):
#    166                                                       ###########################################################
#    167                                                       # Compute the alpha or beta gradient step:
#    168                                                       ############################################################
#    169        24        182.0      7.6      0.0              grad_step = self._grad_alpha if param == "alpha" else self._grad_beta if param == "beta" else None
#    170        24     548623.0  22859.3     99.4              gradpsi_list, gradphi_list, gradreg_list = grad_step(final_target_state, final_gen_state, A, B, type)
#    171
#    172                                                       # Add grad of psi, phi and reg terms
#    173        24        643.0     26.8      0.1              grad_psi_term[:, type] = np.asarray(gradpsi_list)
#    174        24        415.0     17.3      0.1              grad_phi_term[:, type] = np.asarray(gradphi_list)
#    175        24        348.0     14.5      0.1              grad_reg_term[:, type] = np.asarray(gradreg_list)
#    176
#    177         6        336.0     56.0      0.1          grad = np.real(grad_psi_term - grad_phi_term - grad_reg_term)
#    178
#    179         6         33.0      5.5      0.0          return np.asarray(grad)
#
# Total time: 0.0273466 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _grad_alpha at line 181
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    181                                               def _grad_alpha(self, final_target_state, final_gen_state, A: np.ndarray, B: np.ndarray, type: str) -> np.ndarray:
#    182                                                   """Calculate a step of the gradient of the discriminator with respect to alpha.
#    183
#    184                                                   Args:
#    185                                                       final_target_state (np.ndarray): The final target state of the system.
#    186                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    187                                                       A (np.ndarray): expm(-1/lamb * phi), with phi being the matrix repr. of the imag part of the dis.
#    188                                                       B (np.ndarray): expm(1/lamb * psi), with psi being the matrix repr. of the real part of the dis.
#    189                                                       type (str): The type of hermitian operator (0: I, 1: X, 2: Y, 3: Z).
#    190
#    191                                                   Returns:
#    192                                                       tuple: A tuple containing the gradients of psi, phi, and regularization terms.
#    193                                                   """
#    194        12         68.0      5.7      0.0          cs = 1 / lamb
#    195
#    196        12     143280.0  11940.0     52.4          gradpsi: list = self._grad_psi_or_phi(type, respect_to="psi")
#    197        12         43.0      3.6      0.0          gradpsi_list, gradphi_list, gradreg_list = [], [], []
#    198
#    199                                                   # fmt: off
#    200        60        230.0      3.8      0.1          for grad_psi in gradpsi:
#    201                                                       ##################################################################
#    202                                                       # Compute the gradient of psi with respect to alpha
#    203                                                       ##################################################################
#    204        48       9296.0    193.7      3.4              gradpsi_list.append(np.ndarray.item(braket(final_target_state, grad_psi, final_target_state)))
#    205
#    206                                                       ##################################################################
#    207                                                       # No gradient of phi with respect to alpha, so append 0
#    208                                                       ##################################################################
#    209        48        142.0      3.0      0.1              gradphi_list.append(0)
#    210
#    211                                                       ##################################################################
#    212                                                       # Compute the regularization terms:
#    213                                                       ##################################################################
#    214        48      27082.0    564.2      9.9              term1 = cs * braket(final_gen_state, A, final_gen_state) * braket(final_target_state, grad_psi, B, final_target_state)
#    215        48      26815.0    558.6      9.8              term2 = cs * braket(final_gen_state, grad_psi, B, final_target_state) * braket(final_target_state, A, final_gen_state)
#    216        48      26649.0    555.2      9.7              term3 = cs * braket(final_gen_state, A, final_target_state) * braket(final_target_state, grad_psi, B, final_gen_state)
#    217        48      26697.0    556.2      9.8              term4 = cs * braket(final_gen_state, grad_psi, B, final_gen_state) * braket(final_target_state, A, final_target_state)
#    218        48      13114.0    273.2      4.8              gradreg_list.append(np.ndarray.item(lamb / np.e * (cst1 * term1 - cst2 * (term2 + term3) + cst3 * term4)))
#    219                                                   # fmt: on
#    220
#    221        12         50.0      4.2      0.0          return gradpsi_list, gradphi_list, gradreg_list
#
# Total time: 0.0271391 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _grad_beta at line 223
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    223                                               def _grad_beta(self, final_target_state, final_gen_state, A: np.ndarray, B: np.ndarray, type: str):
#    224                                                   """Calculate a step of the gradient of the discriminator with respect to beta.
#    225
#    226                                                   Args:
#    227                                                       final_target_state (np.ndarray): The final target state of the system.
#    228                                                       final_gen_state (np.ndarray): The final gen state of the system.
#    229                                                       A (np.ndarray): expm(-1/lamb * phi), with phi being the matrix repr. of the imag part of the dis.
#    230                                                       B (np.ndarray): expm(1/lamb * psi), with psi being the matrix repr. of the real part of the dis.
#    231                                                       type (str): The type of hermitian operator (0: I, 1: X, 2: Y, 3: Z).
#    232
#    233                                                   Returns:
#    234                                                       tuple: A tuple containing the gradients of psi, phi, and regularization terms.
#    235                                                   """
#    236        12         63.0      5.2      0.0          cs = -1 / lamb
#    237
#    238        12     142032.0  11836.0     52.3          gradphi: list = self._grad_psi_or_phi(type, respect_to="phi")
#    239        12         42.0      3.5      0.0          gradpsi_list, gradphi_list, gradreg_list = [], [], []
#    240
#    241                                                   # fmt: off
#    242        60        249.0      4.2      0.1          for grad_phi in gradphi:
#    243                                                       ##################################################################
#    244                                                       # No gradient of psi with respect to beta, so append 0
#    245                                                       ##################################################################
#    246        48        146.0      3.0      0.1              gradpsi_list.append(0)
#    247
#    248                                                       ##################################################################
#    249                                                       # Compute the gradient of phi with respect to beta
#    250                                                       ##################################################################
#    251        48       8944.0    186.3      3.3              gradphi_list.append(np.ndarray.item(braket(final_gen_state, grad_phi, final_gen_state)))
#    252
#    253                                                       ##################################################################
#    254                                                       # Compute the regularization terms:
#    255                                                       ##################################################################
#    256        48      26840.0    559.2      9.9              term1 = cs * braket(final_gen_state, grad_phi, A, final_gen_state) * braket(final_target_state, B, final_target_state)
#    257        48      26795.0    558.2      9.9              term2 = cs * braket(final_gen_state, B, final_target_state) * braket(final_target_state, grad_phi, A, final_gen_state)
#    258        48      26647.0    555.1      9.8              term3 = cs * braket(final_gen_state, grad_phi, A, final_target_state) * braket(final_target_state, B, final_gen_state)
#    259        48      26631.0    554.8      9.8              term4 = cs * braket(final_gen_state, B, final_gen_state) * braket(final_target_state, grad_phi, A, final_target_state)
#    260        48      12955.0    269.9      4.8              gradreg_list.append(np.ndarray.item(lamb / np.e * (cst1 * term1 - cst2 * (term2 + term3) + cst3 * term4)))
#    261                                                   # fmt: on
#    262
#    263        12         47.0      3.9      0.0          return gradpsi_list, gradphi_list, gradreg_list
#
# Total time: 0.027188 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\discriminator.py
# Function: _grad_psi_or_phi at line 266
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    266                                               def _grad_psi_or_phi(self, type: int, respect_to: str) -> list:
#    267                                                   """Calculate the gradient of the discriminator with respect to psi/phi.
#    268
#    269                                                   Args:
#    270                                                       type (int): The type of hermitian operator (0: I, 1: X, 2: Y, 3: Z).
#    271                                                       psi_or_phi (str): Specify whether to compute the gradient for psi or phi.
#    272
#    273                                                   Returns:
#    274                                                       list: A list of gradients for each qubit in the discriminator, respect psi/phi.
#    275                                                   """
#    276                                                   ########################################################################
#    277                                                   # Chose respect which variable to compute the gradient (alpha or beta)
#    278                                                   ########################################################################
#    279        24        119.0      5.0      0.0          coefficients = self.alpha if respect_to == "psi" else self.beta
#    280
#    281                                                   ########################################################################
#    282                                                   # Compute gradients for each qubit:
#    283                                                   ########################################################################
#    284        24         79.0      3.3      0.0          grad_matrix = []
#    285       120        427.0      3.6      0.2          for i in range(self.size):
#    286        96        261.0      2.7      0.1              grad_matrix_I = 1
#    287       480       1600.0      3.3      0.6              for j in range(self.size):
#    288       384       1105.0      2.9      0.4                  if i == j:
#    289        96        358.0      3.7      0.1                      grad_matrix_j = self.herm[type]
#    290                                                           else:
#    291       288      16271.0     56.5      6.0                      grad_matrix_j = np.zeros_like(self.herm[0], dtype=complex)
#    292      1440       5302.0      3.7      2.0                      for k, herm_k in enumerate(self.herm):
#    293      1152      59733.0     51.9     22.0                          grad_matrix_j += coefficients[j][k] * herm_k
#    294       384     186247.0    485.0     68.5                  grad_matrix_I = np.kron(grad_matrix_I, grad_matrix_j)
#    295        96        303.0      3.2      0.1              grad_matrix.append(grad_matrix_I)
#    296        24         75.0      3.1      0.0          return grad_matrix
#
# Total time: 0.0193189 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\generator.py
# Function: get_total_gen_grad at line 68
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     68                                               def get_total_gen_grad(self, index) -> np.ndarray:
#     69                                                   """Get the total generator gradient for a specific gate index.
#     70
#     71                                                   Args:
#     72                                                       index (int): The index of the gate for which to compute the gradient.
#     73
#     74                                                   Returns:
#     75                                                       np.ndarray: The total generator gradient vector for the specified gate.
#     76                                                   """
#     77        15     192138.0  12809.2     99.5          Untouched_x_G_grad_i = np.kron(Identity(self.config.system_size), self.qc.get_grad_mat_rep(index))
#     78        15       1051.0     70.1      0.5          return np.matmul(Untouched_x_G_grad_i, self.total_input_state)
#
# Total time: 0.0327737 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\generator.py
# Function: update_gen at line 80
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     80                                               def update_gen(self, dis: Discriminator, final_target_state: np.ndarray):
#     81                                                   """Update the generator parameters (angles) using the optimizer.
#     82
#     83                                                   Args:
#     84                                                       dis (Discriminator): The discriminator to compute gradients.
#     85                                                       final_target_state (np.ndarray): The target state vector.
#     86                                                   """
#     87                                                   ###############################################################
#     88                                                   # Compute the gradient
#     89                                                   ###############################################################
#     90         3     294833.0  98277.7     90.0          grad: np.ndarray = self._grad_theta(dis, final_target_state, self.total_gen_state)
#     91
#     92                                                   # Get the new thetas from the gradient
#     93        18        142.0      7.9      0.0          theta = np.asarray([gate.angle for gate in self.qc.gates])
#     94         3       1437.0    479.0      0.4          new_theta = self.optimizer.move_in_grad(theta, grad, "min")
#     95
#     96                                                   ###############################################################
#     97                                                   # Update the angles in the quantum circuit
#     98                                                   ###############################################################
#     99        18         72.0      4.0      0.0          for i in range(self.qc.depth):
#    100        15         71.0      4.7      0.0              self.qc.gates[i].angle = new_theta[i]
#    101
#    102                                                   ###############################################################
#    103                                                   # Update the total generator state with the new angles
#    104                                                   ###############################################################
#    105         3      31182.0  10394.0      9.5          self.total_gen_state = self.get_total_gen_state()
#
# Total time: 0.0293483 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\generator.py
# Function: _grad_theta at line 107
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    107                                               def _grad_theta(
#    108                                                   self,
#    109                                                   dis: Discriminator,
#    110                                                   final_target_state: np.ndarray,
#    111                                                   total_gen_state: np.ndarray,
#    112                                               ) -> np.ndarray:
#    113                                                   """Compute the gradient of the generator parameters (angles) with respect to the discriminator's output.
#    114
#    115                                                   Args:
#    116                                                       dis (Discriminator): The discriminator to compute gradients.
#    117                                                       final_target_state (np.ndarray): The target state vector.
#    118                                                       total_gen_state (np.ndarray): The current generator state vector.
#    119
#    120                                                   Returns:
#    121                                                       np.ndarray: The gradient of the generator parameters.
#    122                                                   """
#    123                                                   #######################################################################
#    124                                                   # Get the current Generator, Target and Discriminator states:
#    125                                                   #######################################################################
#    126         3         85.0     28.3      0.0          final_gen_state = get_final_gen_state_for_discriminator(total_gen_state)
#    127         3      24270.0   8090.0      8.3          A, B, _, phi = dis.get_dis_matrices_rep()
#    128
#    129         3         16.0      5.3      0.0          grad_g_psi, grad_g_phi, grad_g_reg = [], [], []
#    130
#    131        18        133.0      7.4      0.0          for i in range(self.qc.depth):
#    132                                                       # fmt: off
#    133                                                       # For psi term
#    134        15         63.0      4.2      0.0              grad_g_psi.append(0)
#    135
#    136                                                       # For phi term
#    137        15     193761.0  12917.4     66.0              total_gen_grad = self.get_total_gen_grad(i)
#    138        15        335.0     22.3      0.1              final_gen_grad = get_final_gen_state_for_discriminator(total_gen_grad)
#    139        15       6925.0    461.7      2.4              tmp_grad = braket(final_gen_grad, phi, final_gen_state) + braket(final_gen_state, phi, final_gen_grad)
#    140        15        164.0     10.9      0.1              grad_g_phi.append(np.ndarray.item(tmp_grad))
#    141
#    142                                                       # For reg term
#    143        15       7393.0    492.9      2.5              term1 = braket(final_gen_grad, A, final_gen_state) * braket(final_target_state, B, final_target_state)
#    144        15       7111.0    474.1      2.4              term2 = braket(final_gen_state, A, final_gen_grad) * braket(final_target_state, B, final_target_state)
#    145        15       7113.0    474.2      2.4              term3 = braket(final_gen_grad, B, final_target_state) * braket(final_target_state, A, final_gen_state)
#    146        15       7155.0    477.0      2.4              term4 = braket(final_gen_state, B, final_target_state) * braket(final_target_state, A, final_gen_grad)
#    147        15       7097.0    473.1      2.4              term5 = braket(final_gen_grad, A, final_target_state) * braket(final_target_state, B, final_gen_state)
#    148        15       7119.0    474.6      2.4              term6 = braket(final_gen_state, A, final_target_state) * braket(final_target_state, B, final_gen_grad)
#    149        15       7010.0    467.3      2.4              term7 = braket(final_gen_grad, B, final_gen_state) * braket(final_target_state, A, final_target_state)
#    150        15       6865.0    457.7      2.3              term8 = braket(final_gen_state, B, final_gen_grad) * braket(final_target_state, A, final_target_state)
#    151        15      10334.0    688.9      3.5              tmp_reg_grad = self.config.lamb / np.e * (self.config.cst1 * (term1 + term2) - self.config.cst2 * (term3 + term4 + term5 + term6) + self.config.cst3 * (term7 + term8))
#    152
#    153        15        161.0     10.7      0.1              grad_g_reg.append(np.ndarray.item(tmp_reg_grad))
#    154                                                       # fmt: on
#    155
#    156         3         53.0     17.7      0.0          g_psi = np.asarray(grad_g_psi)
#    157         3         44.0     14.7      0.0          g_phi = np.asarray(grad_g_phi)
#    158         3         30.0     10.0      0.0          g_reg = np.asarray(grad_g_reg)
#    159
#    160         3        234.0     78.0      0.1          grad = np.real(g_psi - g_phi - g_reg)
#    161
#    162         3         12.0      4.0      0.0          return np.asarray(grad)
#
# Total time: 0.0974935 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\qgan\training.py
# Function: run at line 59
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     59                                               def run(self):
#     60                                                   """Run the training, saving the data, the model, the logs, and the results plots."""
#     61
#     62                                                   ###########################################################
#     63                                                   # Initialize training
#     64                                                   ###########################################################
#     65         1          6.0      6.0      0.0          if self.verbose:
#     66                                                       print_and_log("\n" + self.config.show_data(), self.config.log_path)
#     67
#     68                                                   # Load models if specified (only the params, and only if compatible)
#     69         1         43.0     43.0      0.0          load_models_if_specified(self, verbose=self.verbose)
#     70
#     71         1          4.0      4.0      0.0          fidelities_history, losses_history = [], []
#     72         1         63.0     63.0      0.0          starttime = datetime.now()
#     73         1          4.0      4.0      0.0          num_epochs: int = 0
#     74
#     75                                                   ###########################################################
#     76                                                   # Main Training Block
#     77                                                   ###########################################################
#     78         1          3.0      3.0      0.0          while True:
#     79                                                       # while (f < 0.95):
#     80         1          4.0      4.0      0.0              fidelities = []
#     81         1          2.0      2.0      0.0              losses = []
#     82         1          4.0      4.0      0.0              num_epochs += 1
#     83         4         27.0      6.8      0.0              for epoch_iter in range(self.config.iterations_epoch):
#     84                                                           ###########################################################
#     85                                                           # Gen and Dis gradient descent
#     86                                                           ###########################################################
#     87         6         36.0      6.0      0.0                  for _ in range(self.config.steps_gen):
#     88         3     328035.0 109345.0     33.6                      self.gen.update_gen(self.dis, self.final_target_state)
#     89
#     90                                                           # Remove ancilla if needed, with ancilla mode, before discriminator:
#     91         3         79.0     26.3      0.0                  final_gen_state = get_final_gen_state_for_discriminator(self.gen.total_gen_state)
#     92
#     93         6         38.0      6.3      0.0                  for _ in range(self.config.steps_dis):
#     94         3     583300.0 194433.3     59.8                      self.dis.update_dis(self.final_target_state, final_gen_state)
#     95
#     96                                                           ###########################################################
#     97                                                           # Every X iterations: compute and save fidelity & loss
#     98                                                           ###########################################################
#     99         3         54.0     18.0      0.0                  if epoch_iter % self.config.save_fid_and_loss_every_x_iter == 0:
#    100         3      32640.0  10880.0      3.3                      fid, loss = compute_fidelity_and_cost(self.dis, self.final_target_state, final_gen_state)
#    101         3         24.0      8.0      0.0                      fidelities.append(fid), losses.append(loss)
#    102
#    103                                                           ############################################################
#    104                                                           # Every X iterations: Print and log fidelity and loss
#    105                                                           ############################################################
#    106         3         21.0      7.0      0.0                  if epoch_iter % self.config.log_every_x_iter == 0:
#    107         2        151.0     75.5      0.0                      info = "\nepoch:{:4d} | iters:{:4d} | fidelity:{:8f} | loss:{:8f}".format(
#    108         1        196.0    196.0      0.0                          num_epochs, epoch_iter + 1, round(fid, 6), round(loss, 6)
#    109                                                               )
#    110         1          7.0      7.0      0.0                      if self.verbose:
#    111                                                                   print_and_log(info, self.config.log_path)
#    112
#    113                                                       ###########################################################
#    114                                                       # End of epoch, store data and plot
#    115                                                       ###########################################################
#    116         1        201.0    201.0      0.0              fidelities_history = np.append(fidelities_history, fidelities)
#    117         1         79.0     79.0      0.0              losses_history = np.append(losses_history, losses)
#    118                                                       #plt_fidelity_vs_iter(fidelities_history, losses_history, CFG, num_epochs)
#    119
#    120                                                       #############################################################
#    121                                                       # Stopping conditions
#    122                                                       #############################################################
#    123         1          3.0      3.0      0.0              if num_epochs >= self.config.epochs:
#    124         1          3.0      3.0      0.0                  if self.verbose:
#    125                                                               print_and_log("\n==================================================\n", self.config.log_path)
#    126                                                               print_and_log(f"\nThe number of epochs exceeds {self.config.epochs}.", self.config.log_path)
#    127         1          4.0      4.0      0.0                  break
#    128
#    129                                                       if fidelities[-1] > self.config.max_fidelity:  # TODO: Maybe change this cond, to use max(fidelities)?
#    130                                                           if self.verbose:
#    131                                                               print_and_log("\n==================================================\n", self.config.log_path)
#    132                                                               print_and_log(
#    133                                                                   f"\nThe fidelity {fidelities[-1]} exceeds the maximum {self.config.max_fidelity}.",
#    134                                                                   self.config.log_path,
#    135                                                               )
#    136                                                           break
#    137
#    138                                                   ###########################################################
#    139                                                   # End training, save all data into files
#    140                                                   ###########################################################
#    141                                                   # Save data of fidelity and loss
#    142         1       9420.0   9420.0      1.0          save_fidelity_loss(fidelities_history, losses_history, self.config.fid_loss_path)
#    143
#    144                                                   # Save data of the generator and the discriminator
#    145         1       5215.0   5215.0      0.5          save_model(self.gen, self.config.model_gen_path)
#    146         1       5041.0   5041.0      0.5          save_model(self.dis, self.config.model_dis_path)
#    147
#    148                                                   # Output the parameters of the generator
#    149         1      10151.0  10151.0      1.0          save_gen_final_params(self.gen, self.config.gen_final_params_path)
#    150
#    151         1         65.0     65.0      0.0          endtime = datetime.now()
#    152         1          7.0      7.0      0.0          if self.verbose:
#    153                                                       print_and_log(f"\nRun took: {endtime - starttime} time.", self.config.log_path)
#    154
#    155         1          5.0      5.0      0.0          return losses_history, fidelities_history
#
# Total time: 0.101463 s
# File: c:\Users\f52ga\CVC\Codes\qgan_subspace\src\tools\training_init.py
# Function: run_single_training at line 35
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     35                                           def run_single_training(config=CFG, verbose=True):
#     36                                               """
#     37                                               Runs a single training instance.
#     38                                               """
#     39         1         13.0     13.0      0.0      if verbose:
#     40                                                   print_and_log("Running in SINGLE RUN mode.\n", config.log_path)
#     41
#     42         1          6.0      6.0      0.0      try:
#     43                                                   ##############################################################
#     44                                                   # Run single training instance with specified configuration
#     45                                                   ##############################################################
#     46         1      39235.0  39235.0      3.9          training_instance = Training(config=config, verbose=verbose)
#     47         1     975360.0 975360.0     96.1          res = training_instance.run()
#     48         1          6.0      6.0      0.0          success_msg = "\nDefault configuration run COMPLETED SUCCESSFULLY.\n"
#     49         1          4.0      4.0      0.0          if verbose:
#     50                                                       print_and_log(success_msg, config.log_path)  # Log to file
#     51         1          3.0      3.0      0.0          return res
#     52
#     53                                               except Exception as e:  # noqa: BLE001
#     54                                                   ##############################################################
#     55                                                   # Handle exceptions during the training run
#     56                                                   ##############################################################
#     57                                                   tb_str = traceback.format_exc()
#     58                                                   error_msg = (
#     59                                                       f"\n{'-' * 60}\n"
#     60                                                       f"FAILED: Default configuration run!\n"
#     61                                                       f"Error Type: {type(e).__name__}\n"
#     62                                                       f"Error Message: {e!s}\n"
#     63                                                       f"Traceback:\n{tb_str}"
#     64                                                       f"{'=' * 60}\n"
#     65                                                   )
#     66                                                   if verbose:
#     67                                                       print_and_log(error_msg, config.log_path)  # Log to file

# %%
# %load_ext scalene
# Out:
# Scalene extension successfully loaded. Note: Scalene currently only
# supports CPU+GPU profiling inside Jupyter notebooks. For full Scalene
# profiling, use the command line version. To profile in line mode, use
# `%scrun [options] statement`. To profile in cell mode, use `%%scalene
# [options]` followed by your code.

# %%
# %%scalene
# run_single_training(config=config, verbose=False)
# Out:
# Scalene: An exception of type ImportError occurred. Arguments:
# ("cannot import name 'display' from 'IPython.core.display' (c:\\Users\\f52ga\\miniforge3\\envs\\qgan\\Lib\\site-packages\\IPython\\core\\display.py)",)
# Traceback (most recent call last):
#   File "c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\scalene\scalene_profiler.py", line 2133, in run_profiler
#     exit_status = profiler.profile_code(
#         code, the_locals, the_globals, left
#     )
#   File "c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\scalene\scalene_profiler.py", line 1868, in profile_code
#     ScaleneJupyter.display_profile(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         port, Scalene.__profiler_html
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\scalene\scalene_jupyter.py", line 35, in display_profile
#     from IPython.core.display import display
# ImportError: cannot import name 'display' from 'IPython.core.display' (c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\IPython\core\display.py)
