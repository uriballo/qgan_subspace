# %%
from config import CFG
from tools.training_init import run_multiple_trainings, run_single_training


##############################################################
# SINGLE RUN mode
##############################################################
def main():
    if CFG.run_multiple_experiments:
        run_multiple_trainings()
    else:
        run_single_training()


if __name__ == "__main__":
    main()
# Out:
# CPU device selected.
# Running in SINGLE RUN mode.
#
#
# ==================================================
# run_timestamp: 2025-07-25__10-27-05,
# ----------------------------------------------
# load_timestamp: None,
# type_of_warm_start: none,
# warm_start_strength: 0.1,
# ----------------------------------------------
# system_size: 3,
# extra_ancilla: False,
# ancilla_mode: pass,
# ancilla_project_norm: re-norm,
# ancilla_topology: bridge,
# ancilla_connect_to: None,
# do_ancilla_1q_gates: False,
# start_ancilla_gates_randomly: False,
# ----------------------------------------------
# gen_layers: 3,
# gen_ansatz: ZZ_X_Z,
# ----------------------------------------------
# target_hamiltonian: custom_h,
# custom_hamiltonian_terms: ['XZ', 'X'],
# custom_hamiltonian_strengths: [1.0, 0.1],
# ----------------------------------------------
# epochs: 10,
# iterations_epoch: 300,
# log_every_x_iter: 10,
# save_fid_and_loss_every_x_iter: 1,
# max_fidelity: 0.99,
# steps_gen: 1,
# steps_dis: 1,
# ----------------------------------------------
# l_rate: 0.01,
# momentum_coeff: 0.9,
# ==================================================
#
#
# Epoch:    1 | Iter:    1 | Fidelity: 0.016954 | Loss: -3.592875
#
# Epoch:    1 | Iter:   11 | Fidelity: 0.022319 | Loss: -3.316858
#
# Epoch:    1 | Iter:   21 | Fidelity: 0.031945 | Loss: -2.938983
#
# Epoch:    1 | Iter:   31 | Fidelity: 0.040195 | Loss: -2.584540
#
# Epoch:    1 | Iter:   41 | Fidelity: 0.046659 | Loss: -1.812008
#
# Epoch:    1 | Iter:   51 | Fidelity: 0.052758 | Loss: -0.293144
#
# Epoch:    1 | Iter:   61 | Fidelity: 0.059611 | Loss: -0.017970
#
# Epoch:    1 | Iter:   71 | Fidelity: 0.067107 | Loss: 0.194352
#
# Epoch:    1 | Iter:   81 | Fidelity: 0.075339 | Loss: 0.255001
#
# Epoch:    1 | Iter:   91 | Fidelity: 0.084443 | Loss: 0.251227
#
# Epoch:    1 | Iter:  101 | Fidelity: 0.094333 | Loss: 0.252956
#
# Epoch:    1 | Iter:  111 | Fidelity: 0.104865 | Loss: 0.252263
#
# Epoch:    1 | Iter:  121 | Fidelity: 0.115934 | Loss: 0.248420
#
# Epoch:    1 | Iter:  131 | Fidelity: 0.127406 | Loss: 0.243283
#
# Epoch:    1 | Iter:  141 | Fidelity: 0.139120 | Loss: 0.237719
#
# Epoch:    1 | Iter:  151 | Fidelity: 0.150913 | Loss: 0.232330
#
# Epoch:    1 | Iter:  161 | Fidelity: 0.162667 | Loss: 0.226774
#
# Epoch:    1 | Iter:  171 | Fidelity: 0.174294 | Loss: 0.221238
#
# Epoch:    1 | Iter:  181 | Fidelity: 0.185762 | Loss: 0.215785
#
# Epoch:    1 | Iter:  191 | Fidelity: 0.197114 | Loss: 0.210347
#
# Epoch:    1 | Iter:  201 | Fidelity: 0.208464 | Loss: 0.204850
#
# Epoch:    1 | Iter:  211 | Fidelity: 0.219996 | Loss: 0.199353
#
# Epoch:    1 | Iter:  221 | Fidelity: 0.231970 | Loss: 0.193408
#
# Epoch:    1 | Iter:  231 | Fidelity: 0.244686 | Loss: 0.187241
#
# Epoch:    1 | Iter:  241 | Fidelity: 0.258485 | Loss: 0.180485
#
# Epoch:    1 | Iter:  251 | Fidelity: 0.273683 | Loss: 0.173003
#
# Epoch:    1 | Iter:  261 | Fidelity: 0.290505 | Loss: 0.165111
#
# Epoch:    1 | Iter:  271 | Fidelity: 0.309008 | Loss: 0.156041
#
# Epoch:    1 | Iter:  281 | Fidelity: 0.328937 | Loss: 0.146140
#
# Epoch:    1 | Iter:  291 | Fidelity: 0.349688 | Loss: 0.135864
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      12         run_single_training()
#      15 if __name__ == "__main__":
# ---> 16     main()
#
# Cell In[1], line 12, in main()
#      10     run_multiple_trainings()
#      11 else:
# ---> 12     run_single_training()
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\tools\training_init.py:46, in run_single_training()
#      41 try:
#      42     ##############################################################
#      43     # Run single training instance with specified configuration
#      44     ##############################################################
#      45     training_instance = Training()
# ---> 46     training_instance.run()
#      47     success_msg = "\nDefault configuration run COMPLETED SUCCESSFULLY.\n"
#      48     print_and_log(success_msg, CFG.log_path)  # Log to file
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\qgan\training.py:87, in Training.run(self)
#      85 self.optimizer_gen.zero_grad()
#      86 # Now, we use the generator's output directly to build the graph
# ---> 87 total_gen_state = self.gen(self.initial_state_total)
#      88 final_gen_state = get_final_gen_state_for_discriminator(total_gen_state)
#      89 # The generator aims to minimize the cost function
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\qgan\generator.py:135, in Generator.forward(self, total_input_state)
#     133 # Get the unitary matrix representation of the quantum circuit
#     134 device = total_input_state.device
# --> 135 generator_unitary = self.ansatz().to(device)
#     137 # The full operator includes the identity on the untouched qubits
#     138 # Identity is created on the correct device by the qgates module
#     139 full_op = torch.kron(Identity(self.target_size), generator_unitary)
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\qgan\generator.py:44, in Ansatz.forward(self)
#      43 def forward(self):
# ---> 44     return self.qc()
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\tools\qobjects\qcircuit.py:56, in QuantumCircuit.forward(self)
#      53 # Apply each gate in sequence
#      54 for gate in self.gates:
#      55     # Get the matrix for the current gate
# ---> 56     g = gate(self.size)
#      57     # Left-multiply the gate to the total circuit matrix
#      58     matrix = torch.matmul(g, matrix)
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\f52ga\miniforge3\envs\qgan\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\tools\qobjects\qgates.py:138, in QuantumGate.forward(self, size)
#     136     return Y_Rotation(size, self.qubit1, self.angle)
#     137 elif self.name == "Z":
# --> 138     return Z_Rotation(size, self.qubit1, self.angle)
#     139 elif self.name == "G":
#     140     return Global_phase(size, self.angle)
#
# File c:\Users\f52ga\CVC\Codes\qgan_subspace-Oriol\qgan_subspace-main\src\tools\qobjects\qgates.py:91, in Z_Rotation(size, qubit, param)
#      89 def Z_Rotation(size: int, qubit: int, param: torch.Tensor) -> torch.Tensor:
#      90     P = _construct_operator(size, {qubit: Z})
# ---> 91     return torch.matrix_exp(-0.5j * param.to(P.device) * P)
#
# KeyboardInterrupt:
